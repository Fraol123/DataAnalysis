# %%
# !pip3 install isoweek

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
from io import StringIO
plt.style.use('ggplot')
plt.style.use('seaborn')
import numpy as np 
from datetime import datetime
from isoweek import Week

# %%
pip install mitosheet
# Out:
# ...
#   Attempting uninstall: plotly
#     Found existing installation: plotly 5.6.0
#     Uninstalling plotly-5.6.0:
#       Successfully uninstalled plotly-5.6.0
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import mitosheet
mitosheet.sheet()
# Out:
# MitoWidget(analysis_data_json='{"analysisName": "id-snnbzbtakl", "analysisToReplay": null, "code": [], "stepSu…

# %%
df = pd.read_csv('all(jan-may).csv')
test = pd.read_csv('all(jan-may).csv')
df.head()
# Out:
#                     Sale ID          User User name User last name   Time  \
# 0  621d35072cea787befff4258  henok.goraye     Henok         Goraye  23:48
# 1  621d35072cea787befff4258  henok.goraye     Henok         Goraye  23:48
# 2  621d34f22cea787befff4254  henok.goraye     Henok         Goraye  23:47
# 3  621d34f22cea787befff4254  henok.goraye     Henok         Goraye  23:47
# 4  621d34f22cea787befff4254  henok.goraye     Henok         Goraye  23:47
#
#          Date                 Outlet ID            Outlet         TIN  \
# 0  28/02/2022  61ebc4512cea787beffafc1c         ER LOUNGE  0058578428
# 1  28/02/2022  61ebc4512cea787beffafc1c         ER LOUNGE  0058578428
# 2  28/02/2022  6159f38bbab1dd88bd6a35e5  Halefom Stockist         NaN
# 3  28/02/2022  6159f38bbab1dd88bd6a35e5  Halefom Stockist         NaN
# 4  28/02/2022  6159f38bbab1dd88bd6a35e5  Halefom Stockist         NaN
#
#        Outlet Segment  ... Price with VAT Item name Item quantity  \
# ...

# %%
test['Outlet ID'].value_counts()
# Out:
# 61d2be462cea787beff971f1    256
# 61d2c6b32cea787beff975ae    247
# 61de932f2cea787beffa32eb    204
# 6159f38bbab1dd88bd6a3a2b    203
# 61de94ce2cea787beffa337c    200
#                            ...
# 6159f38bbab1dd88bd6a2fd4      1
# 6159f38bbab1dd88bd6a424b      1
# 6159f38bbab1dd88bd6a479c      1
# 6159f38bbab1dd88bd6a4613      1
# 6159f38bbab1dd88bd6a3d26      1
# Name: Outlet ID, Length: 8064, dtype: int64

# %% [markdown]
# # getting first purchase dates

# %%
test.head()
# Out:
#                     Sale ID          User User name User last name   Time  \
# 0  621d35072cea787befff4258  henok.goraye     Henok         Goraye  23:48
# 1  621d35072cea787befff4258  henok.goraye     Henok         Goraye  23:48
# 2  621d34f22cea787befff4254  henok.goraye     Henok         Goraye  23:47
# 3  621d34f22cea787befff4254  henok.goraye     Henok         Goraye  23:47
# 4  621d34f22cea787befff4254  henok.goraye     Henok         Goraye  23:47
#
#          Date                 Outlet ID            Outlet         TIN  \
# 0  28/02/2022  61ebc4512cea787beffafc1c         ER LOUNGE  0058578428
# 1  28/02/2022  61ebc4512cea787beffafc1c         ER LOUNGE  0058578428
# 2  28/02/2022  6159f38bbab1dd88bd6a35e5  Halefom Stockist         NaN
# 3  28/02/2022  6159f38bbab1dd88bd6a35e5  Halefom Stockist         NaN
# 4  28/02/2022  6159f38bbab1dd88bd6a35e5  Halefom Stockist         NaN
#
#        Outlet Segment  ... Price with VAT Item name Item quantity  \
# ...

# %%
test.shape
# Out:
# (152020, 26)

# %%
#Changing date
test['Date'] = pd.to_datetime(test['Date'], infer_datetime_format=True)

# %%
test.head()
# Out:
#                     Sale ID          User User name User last name   Time  \
# 0  621d35072cea787befff4258  henok.goraye     Henok         Goraye  23:48
# 1  621d35072cea787befff4258  henok.goraye     Henok         Goraye  23:48
# 2  621d34f22cea787befff4254  henok.goraye     Henok         Goraye  23:47
# 3  621d34f22cea787befff4254  henok.goraye     Henok         Goraye  23:47
# 4  621d34f22cea787befff4254  henok.goraye     Henok         Goraye  23:47
#
#         Date                 Outlet ID            Outlet         TIN  \
# 0 2022-02-28  61ebc4512cea787beffafc1c         ER LOUNGE  0058578428
# 1 2022-02-28  61ebc4512cea787beffafc1c         ER LOUNGE  0058578428
# 2 2022-02-28  6159f38bbab1dd88bd6a35e5  Halefom Stockist         NaN
# 3 2022-02-28  6159f38bbab1dd88bd6a35e5  Halefom Stockist         NaN
# 4 2022-02-28  6159f38bbab1dd88bd6a35e5  Halefom Stockist         NaN
#
#        Outlet Segment  ... Price with VAT Item name Item quantity  \
# ...

# %% [markdown]
# #### changing date to m-d-y format

# %%
test['Date'] = pd.to_datetime(test.Date, format='%Y-%m-%d %H:%M:%S')

# %%
test['Date'] = pd.to_datetime(test.Date, format='%Y-%m-%d')

# %%
test['Date'] = test['Date'].dt.strftime('%m-%d-%Y')

# %%
test.head()
# Out:
#                     Sale ID          User User name User last name   Time  \
# 0  621d35072cea787befff4258  henok.goraye     Henok         Goraye  23:48
# 1  621d35072cea787befff4258  henok.goraye     Henok         Goraye  23:48
# 2  621d34f22cea787befff4254  henok.goraye     Henok         Goraye  23:47
# 3  621d34f22cea787befff4254  henok.goraye     Henok         Goraye  23:47
# 4  621d34f22cea787befff4254  henok.goraye     Henok         Goraye  23:47
#
#          Date                 Outlet ID            Outlet         TIN  \
# 0  02-28-2022  61ebc4512cea787beffafc1c         ER LOUNGE  0058578428
# 1  02-28-2022  61ebc4512cea787beffafc1c         ER LOUNGE  0058578428
# 2  02-28-2022  6159f38bbab1dd88bd6a35e5  Halefom Stockist         NaN
# 3  02-28-2022  6159f38bbab1dd88bd6a35e5  Halefom Stockist         NaN
# 4  02-28-2022  6159f38bbab1dd88bd6a35e5  Halefom Stockist         NaN
#
#        Outlet Segment  ... Price with VAT Item name Item quantity  \
# ...

# %%
test.shape
# Out:
# (152020, 26)

# %%
test = test.fillna(0)

# %%
test['Month'] = test['Date'].str[0:2] # getting the first 2 charchters

# %%
test.head()
# Out:
#                     Sale ID          User User name User last name   Time  \
# 0  621d35072cea787befff4258  henok.goraye     Henok         Goraye  23:48
# 1  621d35072cea787befff4258  henok.goraye     Henok         Goraye  23:48
# 2  621d34f22cea787befff4254  henok.goraye     Henok         Goraye  23:47
# 3  621d34f22cea787befff4254  henok.goraye     Henok         Goraye  23:47
# 4  621d34f22cea787befff4254  henok.goraye     Henok         Goraye  23:47
#
#          Date                 Outlet ID            Outlet         TIN  \
# 0  02-28-2022  61ebc4512cea787beffafc1c         ER LOUNGE  0058578428
# 1  02-28-2022  61ebc4512cea787beffafc1c         ER LOUNGE  0058578428
# 2  02-28-2022  6159f38bbab1dd88bd6a35e5  Halefom Stockist           0
# 3  02-28-2022  6159f38bbab1dd88bd6a35e5  Halefom Stockist           0
# 4  02-28-2022  6159f38bbab1dd88bd6a35e5  Halefom Stockist           0
#
#        Outlet Segment  ... Item name Item quantity Item price without VAT  \
# ...

# %%
test['date'] = pd.to_datetime(test['Date'])

# %%
del test['Date']

# %%
test.head()
# Out:
#                     Sale ID          User User name User last name   Time  \
# 0  621d35072cea787befff4258  henok.goraye     Henok         Goraye  23:48
# 1  621d35072cea787befff4258  henok.goraye     Henok         Goraye  23:48
# 2  621d34f22cea787befff4254  henok.goraye     Henok         Goraye  23:47
# 3  621d34f22cea787befff4254  henok.goraye     Henok         Goraye  23:47
# 4  621d34f22cea787befff4254  henok.goraye     Henok         Goraye  23:47
#
#                   Outlet ID            Outlet         TIN      Outlet Segment  \
# 0  61ebc4512cea787beffafc1c         ER LOUNGE  0058578428         Club/lounge
# 1  61ebc4512cea787beffafc1c         ER LOUNGE  0058578428         Club/lounge
# 2  6159f38bbab1dd88bd6a35e5  Halefom Stockist           0  Bar And Restaurant
# 3  6159f38bbab1dd88bd6a35e5  Halefom Stockist           0  Bar And Restaurant
# 4  6159f38bbab1dd88bd6a35e5  Halefom Stockist           0  Bar And Restaurant
#
# ...

# %%
test.tail()
# Out:
#                          Sale ID             User User name User last name  \
# 152015  621e2c892cea787befff5d64  lamrot.werkineh    Lamrot       Werkineh
# 152016  621da9eb2cea787befff44cc     tenaye.gebru    Tenaye          Gebru
# 152017  621da9eb2cea787befff44ca     tenaye.gebru    Tenaye          Gebru
# 152018  621da9eb2cea787befff44ca     tenaye.gebru    Tenaye          Gebru
# 152019  621da9eb2cea787befff44ca     tenaye.gebru    Tenaye          Gebru
#
#          Time                 Outlet ID                    Outlet         TIN  \
# 152015  07:13  6159f38bbab1dd88bd6a3a6b             Maal Rakkatee  0072830399
# 152016  07:07  6159f38bbab1dd88bd6a3e5b                 Mulat Bar           0
# 152017  06:56  6159f38bbab1dd88bd6a3942  Kiru Bar Ena Restaurant   0013796976
# 152018  06:56  6159f38bbab1dd88bd6a3942  Kiru Bar Ena Restaurant   0013796976
# 152019  06:56  6159f38bbab1dd88bd6a3942  Kiru Bar Ena Restaurant   0013796976
#
# ...

# %%
#changing to iso week
test['Week_Number'] = test['date'].dt.week
# Out:
# C:\Users\Fraol\AppData\Local\Temp/ipykernel_848/1154416236.py:2: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated.  Please use Series.dt.isocalendar().week instead.
#   test['Week_Number'] = test['date'].dt.week

# %%
test.tail(100)
# Out:
#                          Sale ID               User  User name User last name  \
# 151920  621deba52cea787befff5262  mikiyas.alemayehu    Mikiyas      Alemayehu
# 151921  621deba52cea787befff5262  mikiyas.alemayehu    Mikiyas      Alemayehu
# 151922  621db5932cea787befff463b  mekuanint.tamirat  Mekuanint        Tamirat
# 151923  621db58e2cea787befff4637      tangut.tewabe     Tangut         Tewabe
# 151924  621db58e2cea787befff4637      tangut.tewabe     Tangut         Tewabe
# ...                          ...                ...        ...            ...
# 152015  621e2c892cea787befff5d64    lamrot.werkineh     Lamrot       Werkineh
# 152016  621da9eb2cea787befff44cc       tenaye.gebru     Tenaye          Gebru
# 152017  621da9eb2cea787befff44ca       tenaye.gebru     Tenaye          Gebru
# 152018  621da9eb2cea787befff44ca       tenaye.gebru     Tenaye          Gebru
# 152019  621da9eb2cea787befff44ca       tenaye.gebru     Tenaye          Gebru
#
# ...

# %%
start_of_purchase= test[['Outlet ID','Territory','Area','Outlet','date','Week_Number','Item name','Item quantity']].copy()
start_of_purchase.head()
# Out:
#                   Outlet ID              Territory               Area  \
# 0  61ebc4512cea787beffafc1c  NORTH - CENTRAL ADDIS  URAEL - MEGENAGNA
# 1  61ebc4512cea787beffafc1c  NORTH - CENTRAL ADDIS  URAEL - MEGENAGNA
# 2  6159f38bbab1dd88bd6a35e5  NORTH - CENTRAL ADDIS  URAEL - MEGENAGNA
# 3  6159f38bbab1dd88bd6a35e5  NORTH - CENTRAL ADDIS  URAEL - MEGENAGNA
# 4  6159f38bbab1dd88bd6a35e5  NORTH - CENTRAL ADDIS  URAEL - MEGENAGNA
#
#              Outlet       date  Week_Number Item name  Item quantity
# 0         ER LOUNGE 2022-02-28            9     Apple              1
# 1         ER LOUNGE 2022-02-28            9      Lime              1
# 2  Halefom Stockist 2022-02-28            9     Apple              1
# 3  Halefom Stockist 2022-02-28            9      Lime              2
# 4  Halefom Stockist 2022-02-28            9        PG              1

# %%
# to see if the file is correct
df3.to_csv('check.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7512/1855741177.py in <module>
#       1 # to see if the file is correct
# ----> 2 df3.to_csv('check.csv', index=False)
#
# NameError: name 'df3' is not defined

# %%
delivery = test[['Outlet ID','Territory','Area','Outlet','date']].copy()
delivery.head()
# Out:
#                   Outlet ID              Territory               Area  \
# 0  61ebc4512cea787beffafc1c  NORTH - CENTRAL ADDIS  URAEL - MEGENAGNA
# 1  61ebc4512cea787beffafc1c  NORTH - CENTRAL ADDIS  URAEL - MEGENAGNA
# 2  6159f38bbab1dd88bd6a35e5  NORTH - CENTRAL ADDIS  URAEL - MEGENAGNA
# 3  6159f38bbab1dd88bd6a35e5  NORTH - CENTRAL ADDIS  URAEL - MEGENAGNA
# 4  6159f38bbab1dd88bd6a35e5  NORTH - CENTRAL ADDIS  URAEL - MEGENAGNA
#
#              Outlet       date
# 0         ER LOUNGE 2022-02-28
# 1         ER LOUNGE 2022-02-28
# 2  Halefom Stockist 2022-02-28
# 3  Halefom Stockist 2022-02-28
# 4  Halefom Stockist 2022-02-28

# %%
#delivery.shape
delivery['Outlet ID'].value_counts()
# Out:
# 61d2be462cea787beff971f1    256
# 61d2c6b32cea787beff975ae    247
# 61de932f2cea787beffa32eb    204
# 6159f38bbab1dd88bd6a3a2b    203
# 61de94ce2cea787beffa337c    200
#                            ...
# 6159f38bbab1dd88bd6a2fd4      1
# 6159f38bbab1dd88bd6a424b      1
# 6159f38bbab1dd88bd6a479c      1
# 6159f38bbab1dd88bd6a4613      1
# 6159f38bbab1dd88bd6a3d26      1
# Name: Outlet ID, Length: 8064, dtype: int64

# %%
delivery['Total_delivery'] = test.groupby('Outlet ID')['date'].transform('count')
#delivery['Number of delivery'] = test.groupby('Outlet ID')['Outlet ID'].cumcount() + 1
delivery.head()
# Out:
#                   Outlet ID              Territory               Area  \
# 0  61ebc4512cea787beffafc1c  NORTH - CENTRAL ADDIS  URAEL - MEGENAGNA
# 1  61ebc4512cea787beffafc1c  NORTH - CENTRAL ADDIS  URAEL - MEGENAGNA
# 2  6159f38bbab1dd88bd6a35e5  NORTH - CENTRAL ADDIS  URAEL - MEGENAGNA
# 3  6159f38bbab1dd88bd6a35e5  NORTH - CENTRAL ADDIS  URAEL - MEGENAGNA
# 4  6159f38bbab1dd88bd6a35e5  NORTH - CENTRAL ADDIS  URAEL - MEGENAGNA
#
#              Outlet       date  Total_delivery
# 0         ER LOUNGE 2022-02-28              30
# 1         ER LOUNGE 2022-02-28              30
# 2  Halefom Stockist 2022-02-28              65
# 3  Halefom Stockist 2022-02-28              65
# 4  Halefom Stockist 2022-02-28              65

# %%
#delivery.head()
delivery['Outlet ID'].value_counts()
# Out:
# 61d2be462cea787beff971f1    256
# 61d2c6b32cea787beff975ae    247
# 61de932f2cea787beffa32eb    204
# 6159f38bbab1dd88bd6a3a2b    203
# 61de94ce2cea787beffa337c    200
#                            ...
# 6159f38bbab1dd88bd6a2fd4      1
# 6159f38bbab1dd88bd6a424b      1
# 6159f38bbab1dd88bd6a479c      1
# 6159f38bbab1dd88bd6a4613      1
# 6159f38bbab1dd88bd6a3d26      1
# Name: Outlet ID, Length: 8064, dtype: int64

# %%
delivery.to_csv('delivery.csv', index=False)

# %%
QuantityT['Outlet ID'].value_counts()
# Out:
# 6159f38bbab1dd88bd6a26b9    1
# 6159f38bbab1dd88bd6a4998    1
# 6159f38bbab1dd88bd6a49ad    1
# 6159f38bbab1dd88bd6a49ab    1
# 6159f38bbab1dd88bd6a49aa    1
#                            ..
# 6159f38bbab1dd88bd6a37d2    1
# 6159f38bbab1dd88bd6a37d1    1
# 6159f38bbab1dd88bd6a37d0    1
# 6159f38bbab1dd88bd6a37cf    1
# 628384392cea787bef08a5f3    1
# Name: Outlet ID, Length: 8026, dtype: int64

# %%
QuantityT = pd.read_csv('QuantityT.csv')

# %%
QuantityT =QuantityT.fillna(0)
QuantityT.head()
# Out:
#                   Outlet ID           Territory  \
# 0  6159f38bbab1dd88bd6a26b9          EAST ADDIS
# 1  6159f38bbab1dd88bd6a26ba  ADAMA -ZEWAY-CHERO
# 2  6159f38bbab1dd88bd6a26bd         SOUTH ADDIS
# 3  6159f38bbab1dd88bd6a26be  ADAMA -ZEWAY-CHERO
# 4  6159f38bbab1dd88bd6a26bf          WEST ADDIS
#
#                               Area                        Outlet  Apple  GHL  \
# 0                       CMC - GORO              Adane Resraurant    0.0  0.0
# 1                    ADAMA - WENJI   Cheru Medhanialem Butchery    15.0  3.0
# 2  MASELETEGNA - AKAKI- TULU DIMTU            Rame Royal Grocery    0.0  0.0
# 3                DUKEM - DEBREZEIT            Shenen Bin Garden     7.0  0.0
# 4             TOREHAYLOCH - WELETE               Sodo Menech Bar    0.0  2.0
#
#     Lime    PG  Total
# 0    2.0   4.0      6
# 1  116.0  28.0    162
# 2    3.0   1.0      4
# 3   13.0   5.0     25
# 4    4.0   0.0      6

# %%
#Saving pivot table to excel

writer = pd.ExcelWriter('Quantity.xlsx', engine='xlsxwriter')
Quantity.to_excel(writer,sheet_name='dataframe')
writer.save()

# %%
Quantity.to_csv('Quantity.csv', index=False)

# %%
QuantityT .shape
# Out:
# (8063, 9)

# %%
test.head()
# Out:
#                     Sale ID          User User name User last name   Time  \
# 0  621d35072cea787befff4258  henok.goraye     Henok         Goraye  23:48
# 1  621d35072cea787befff4258  henok.goraye     Henok         Goraye  23:48
# 2  621d34f22cea787befff4254  henok.goraye     Henok         Goraye  23:47
# 3  621d34f22cea787befff4254  henok.goraye     Henok         Goraye  23:47
# 4  621d34f22cea787befff4254  henok.goraye     Henok         Goraye  23:47
#
#                   Outlet ID            Outlet         TIN      Outlet Segment  \
# 0  61ebc4512cea787beffafc1c         ER LOUNGE  0058578428         Club/lounge
# 1  61ebc4512cea787beffafc1c         ER LOUNGE  0058578428         Club/lounge
# 2  6159f38bbab1dd88bd6a35e5  Halefom Stockist           0  Bar And Restaurant
# 3  6159f38bbab1dd88bd6a35e5  Halefom Stockist           0  Bar And Restaurant
# 4  6159f38bbab1dd88bd6a35e5  Halefom Stockist           0  Bar And Restaurant
#
# ...

# %%
#test['start of purchase'] = test['Week_Number'].min()


#del test['start of purchase']
test.head()
# Out:
#                     Sale ID          User User name User last name   Time  \
# 0  621d35072cea787befff4258  henok.goraye     Henok         Goraye  23:48
# 1  621d35072cea787befff4258  henok.goraye     Henok         Goraye  23:48
# 2  621d34f22cea787befff4254  henok.goraye     Henok         Goraye  23:47
# 3  621d34f22cea787befff4254  henok.goraye     Henok         Goraye  23:47
# 4  621d34f22cea787befff4254  henok.goraye     Henok         Goraye  23:47
#
#          Date                 Outlet ID            Outlet         TIN  \
# 0  28/02/2022  61ebc4512cea787beffafc1c         ER LOUNGE  0058578428
# 1  28/02/2022  61ebc4512cea787beffafc1c         ER LOUNGE  0058578428
# 2  28/02/2022  6159f38bbab1dd88bd6a35e5  Halefom Stockist         NaN
# 3  28/02/2022  6159f38bbab1dd88bd6a35e5  Halefom Stockist         NaN
# 4  28/02/2022  6159f38bbab1dd88bd6a35e5  Halefom Stockist         NaN
#
#        Outlet Segment  ... Price with VAT Item name Item quantity  \
# ...

# %%
test.to_csv('test.csv', index=False)

# %%
#res = test.groupby('Outlet ID').agg({'Week_Number': min})
#res.insert(0, 'Outlet', test.set_index('Outlet ID'))
#res.reset_index()
test['first_purchase'] = test.groupby('Outlet ID').agg({'Week_Number': min},np.insert(0, 'Outlet', test.set_index('Outlet ID')))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_956/2496952919.py in <module>
#       2 #res.insert(0, 'Outlet', test.set_index('Outlet ID'))
#       3 #res.reset_index()
# ----> 4 test['first_purchase'] = test.groupby('Outlet ID').agg({'Week_Number': min},np.insert(0, 'Outlet', test.set_index('Outlet ID')))
#
# <__array_function__ internals> in insert(*args, **kwargs)
#
# ~\anaconda3\lib\site-packages\numpy\lib\function_base.py in insert(arr, obj, values, axis)
#    4629     if indices.size == 1:
#    4630         index = indices.item()
# -> 4631         if index < -N or index > N:
#    4632             raise IndexError(
#    4633                 "index %i is out of bounds for axis %i with "
#
# TypeError: '<' not supported between instances of 'str' and 'int'

# %%
#Quantity = pd.read_csv('Qt.csv')
QuantityT = QuantityT.fillna(0)
QuantityT.head()
# Out:
#                   Outlet ID           Territory  \
# 0  6159f38bbab1dd88bd6a26b9          EAST ADDIS
# 1  6159f38bbab1dd88bd6a26ba  ADAMA -ZEWAY-CHERO
# 2  6159f38bbab1dd88bd6a26bd         SOUTH ADDIS
# 3  6159f38bbab1dd88bd6a26be  ADAMA -ZEWAY-CHERO
# 4  6159f38bbab1dd88bd6a26bf          WEST ADDIS
#
#                               Area                        Outlet  Apple  GHL  \
# 0                       CMC - GORO              Adane Resraurant    0.0  0.0
# 1                    ADAMA - WENJI   Cheru Medhanialem Butchery    15.0  3.0
# 2  MASELETEGNA - AKAKI- TULU DIMTU            Rame Royal Grocery    0.0  0.0
# 3                DUKEM - DEBREZEIT            Shenen Bin Garden     7.0  0.0
# 4             TOREHAYLOCH - WELETE               Sodo Menech Bar    0.0  2.0
#
#     Lime    PG  Total
# 0    2.0   4.0      6
# 1  116.0  28.0    162
# 2    3.0   1.0      4
# 3   13.0   5.0     25
# 4    4.0   0.0      6

# %%
see =pd.concat([delivery,QuantityT]).drop_duplicates().reset_index(drop=True)
see.head()
# Out:
#                   Outlet ID              Territory               Area  \
# 0  61ebc4512cea787beffafc1c  NORTH - CENTRAL ADDIS  URAEL - MEGENAGNA
# 1  6159f38bbab1dd88bd6a35e5  NORTH - CENTRAL ADDIS  URAEL - MEGENAGNA
# 2  6159f38bbab1dd88bd6a3fe5  NORTH - CENTRAL ADDIS  URAEL - MEGENAGNA
# 3  6159f38bbab1dd88bd6a27b2  NORTH - CENTRAL ADDIS  URAEL - MEGENAGNA
# 4  6159f38bbab1dd88bd6a3a0d  NORTH - CENTRAL ADDIS  URAEL - MEGENAGNA
#
#              Outlet       date  Total_delivery  Apple  GHL  Lime  PG  Total
# 0         ER LOUNGE 2022-02-28            30.0    NaN  NaN   NaN NaN    NaN
# 1  Halefom Stockist 2022-02-28            65.0    NaN  NaN   NaN NaN    NaN
# 2       Ozone Hotel 2022-02-28            89.0    NaN  NaN   NaN NaN    NaN
# 3    Aberus Grocery 2022-02-28            26.0    NaN  NaN   NaN NaN    NaN
# 4         Libro Bar 2022-02-28            98.0    NaN  NaN   NaN NaN    NaN

# %%
see = see.fillna(0)
see.tail()
# Out:
#                       Outlet ID                     Territory  \
# 81730  628498cd2cea787bef08b815  SHASHEMNE - HAWASSA - NEGELE
# 81731  6284bd452cea787bef08bd62            ADAMA -ZEWAY-CHERO
# 81732  6284c9f82cea787bef08bf56            DEREDAWA - JIGJIGA
# 81733  6284f0592cea787bef08c63f            ADAMA -ZEWAY-CHERO
# 81734  6285eacd2cea787bef08d5ec            ADAMA -ZEWAY-CHERO
#
#                           Area             Outlet date  Total_delivery  Apple  \
# 81730        DILLA - BULE HORA      birhanu stock    0             0.0    3.0
# 81731  ZEWAY - MEKI - BUTAGIRA      megersa Hotel    0             0.0    2.0
# 81732               DEREDAWA 1       Abem Grocery    0             0.0   13.0
# 81733  ZEWAY - MEKI - BUTAGIRA       Hayle Resort    0             0.0    0.0
# 81734  ZEWAY - MEKI - BUTAGIRA  Shewa Ber Buchery    0             0.0    1.0
#
#        GHL  Lime    PG  Total
# 81730  2.0  20.0   4.0   29.0
# 81731  0.0   3.0   0.0    5.0
# ...

# %%
#see.shape
see['Outlet ID'].value_counts()
# Out:
# 61d2c6b32cea787beff975ae    95
# 61d2be462cea787beff971f1    88
# 61de94ce2cea787beffa337c    86
# 61d2c33e2cea787beff97432    86
# 61d2b56b2cea787beff96f7e    81
#                             ..
# 625115722cea787bef03d9c8     2
# 6159f38bbab1dd88bd6a3e1e     2
# 6159f38bbab1dd88bd6a290b     2
# 6159f38bbab1dd88bd6a4627     2
# 6159f38bbab1dd88bd6a3f79     1
# Name: Outlet ID, Length: 8064, dtype: int64

# %%
new_out = pd.merge(delivery, QuantityT,
               on=['Outlet ID', 'Territory', 'Area', 'Outlet'],
               how='outer').fillna(0)
new_out.head()
# Out:
#                   Outlet ID              Territory               Area  \
# 0  61ebc4512cea787beffafc1c  NORTH - CENTRAL ADDIS  URAEL - MEGENAGNA
# 1  61ebc4512cea787beffafc1c  NORTH - CENTRAL ADDIS  URAEL - MEGENAGNA
# 2  61ebc4512cea787beffafc1c  NORTH - CENTRAL ADDIS  URAEL - MEGENAGNA
# 3  61ebc4512cea787beffafc1c  NORTH - CENTRAL ADDIS  URAEL - MEGENAGNA
# 4  61ebc4512cea787beffafc1c  NORTH - CENTRAL ADDIS  URAEL - MEGENAGNA
#
#       Outlet                 date  Total_delivery  Apple  GHL  Lime    PG  \
# 0  ER LOUNGE  2022-02-28 00:00:00            30.0    9.0  4.0  23.0  12.0
# 1  ER LOUNGE  2022-02-28 00:00:00            30.0    9.0  4.0  23.0  12.0
# 2  ER LOUNGE  2022-02-26 00:00:00            30.0    9.0  4.0  23.0  12.0
# 3  ER LOUNGE  2022-02-26 00:00:00            30.0    9.0  4.0  23.0  12.0
# 4  ER LOUNGE  2022-02-26 00:00:00            30.0    9.0  4.0  23.0  12.0
#
#    Total
# 0   48.0
# 1   48.0
# 2   48.0
# 3   48.0
# 4   48.0

# %%
see.shape
# Out:
# (81735, 11)

# %%
see.drop('Apple', axis=1, inplace=True)
see.drop('GHL',axis=1,inplace=True)
see.drop('Lime' ,axis=1,inplace=True)
see.drop('PG',axis=1, inplace=True)

# %%
#new_out.shape
see['Outlet ID'].value_counts()
# Out:
# 61d2c6b32cea787beff975ae    95
# 61d2be462cea787beff971f1    88
# 61de94ce2cea787beffa337c    86
# 61d2c33e2cea787beff97432    86
# 61d2b56b2cea787beff96f7e    81
#                             ..
# 625115722cea787bef03d9c8     2
# 6159f38bbab1dd88bd6a3e1e     2
# 6159f38bbab1dd88bd6a290b     2
# 6159f38bbab1dd88bd6a4627     2
# 6159f38bbab1dd88bd6a3f79     1
# Name: Outlet ID, Length: 8064, dtype: int64

# %%
see.head()
# Out:
#                   Outlet ID              Territory               Area  \
# 0  61ebc4512cea787beffafc1c  NORTH - CENTRAL ADDIS  URAEL - MEGENAGNA
# 1  6159f38bbab1dd88bd6a35e5  NORTH - CENTRAL ADDIS  URAEL - MEGENAGNA
# 2  6159f38bbab1dd88bd6a3fe5  NORTH - CENTRAL ADDIS  URAEL - MEGENAGNA
# 3  6159f38bbab1dd88bd6a27b2  NORTH - CENTRAL ADDIS  URAEL - MEGENAGNA
# 4  6159f38bbab1dd88bd6a3a0d  NORTH - CENTRAL ADDIS  URAEL - MEGENAGNA
#
#              Outlet                 date  Total_delivery  Total
# 0         ER LOUNGE  2022-02-28 00:00:00            30.0    0.0
# 1  Halefom Stockist  2022-02-28 00:00:00            65.0    0.0
# 2       Ozone Hotel  2022-02-28 00:00:00            89.0    0.0
# 3    Aberus Grocery  2022-02-28 00:00:00            26.0    0.0
# 4         Libro Bar  2022-02-28 00:00:00            98.0    0.0

# %%
writer = pd.ExcelWriter('merged.xlsx', engine='xlsxwriter')
merged.to_excel(writer,sheet_name='dataframe')
writer.save()

# %%
see =see.to_csv('see.csv',index=False)

# %%
df = pd.merge(see,test[['Outlet ID','Week_Number']],on='Outlet ID', how='left')
df.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7856/2869765025.py in <module>
# ----> 1 df = pd.merge(see,test[['Outlet ID','Week_Number']],on='Outlet ID', how='left')
#       2 df.head()
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     104     validate: str | None = None,
#     105 ) -> DataFrame:
# --> 106     op = _MergeOperation(
#     107         left,
#     108         right,
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     625         validate: str | None = None,
#     626     ):
# --> 627         _left = _validate_operand(left)
# ...

# %%
#df.shape
df['Outlet ID'].value_counts()
# Out:
# 61d2be462cea787beff971f1    62500
# 61d2c6b32cea787beff975ae    57121
# 61de932f2cea787beffa32eb    40401
# 6159f38bbab1dd88bd6a3a2b    40000
# 61de94ce2cea787beffa337c    38025
#                             ...
# 6159f38bbab1dd88bd6a43e9        1
# 6159f38bbab1dd88bd6a39a5        1
# 6159f38bbab1dd88bd6a4671        1
# 6159f38bbab1dd88bd6a334a        1
# 6159f38bbab1dd88bd6a4907        1
# Name: Outlet ID, Length: 8027, dtype: int64

# %%
#New_merged = pd.merge(df, test,on="Outlet ID")
#New_merged.tail()
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7512/2253086967.py in <module>
# ----> 1 New_merged = pd.merge(df, test,on="Outlet ID")
#       2 New_merged.tail()
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     119         validate=validate,
#     120     )
# --> 121     return op.get_result()
#     122
#     123
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in get_result(self)
#     713             self.left, self.right = self._indicator_pre_merge(self.left, self.right)
#     714
# --> 715         join_index, left_indexer, right_indexer = self._get_join_info()
#     716
#     717         llabels, rlabels = _items_overlap_with_suffix(
#
# ...

# %%
Summery = New_merged[['Outlet ID','Territory_x','Area_x','Outlet_x','Week_Number','Quantity(Total)','Total_delivery']].copy()
Summery.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7512/2704933944.py in <module>
# ----> 1 Summery = New_merged[['Outlet ID','Territory_x','Area_x','Outlet_x','Week_Number','Quantity(Total)','Total_delivery']].copy()
#       2 Summery.head()
#
# NameError: name 'New_merged' is not defined

# %%
['Week of Analysis'] = 19
.head()
# Out:
#   File "C:\Users\Fraol\AppData\Local\Temp/ipykernel_7512/411484960.py", line 1
#     ['Week of Analysis'] = 19
#      ^
# SyntaxError: cannot assign to literal

# %%
df.to_excel('Summery2.xlsx')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7856/2504678606.py in <module>
# ----> 1 df.to_excel('Summery2.xlsx')
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, encoding, inf_rep, verbose, freeze_panes, storage_options)
#    2282             inf_rep=inf_rep,
#    2283         )
# -> 2284         formatter.write(
#    2285             excel_writer,
#    2286             sheet_name=sheet_name,
#
# ~\anaconda3\lib\site-packages\pandas\io\formats\excel.py in write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine, storage_options)
#     821         num_rows, num_cols = self.df.shape
#     822         if num_rows > self.max_rows or num_cols > self.max_cols:
# ...

# %%
Summery =df.to_csv('Summery2.csv',index=False)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7856/3534028993.py in <module>
# ----> 1 Summery =df.to_csv('Summery2.csv',index=False)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3464         )
#    3465
# -> 3466         return DataFrameRenderer(formatter).to_csv(
#    3467             path_or_buf,
#    3468             line_terminator=line_terminator,
#
# ...

# %%
df.shape
# Out:
# (6372468, 8)

# %%
Summery['Outlet ID'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7856/2067950565.py in <module>
# ----> 1 Summery['Outlet ID'].value_counts()
#
# TypeError: 'NoneType' object is not subscriptable

# %%
outlet_id =df['Outlet ID'].value_counts()
outlet_id
# Out:
# 61d2be462cea787beff971f1    62500
# 61d2c6b32cea787beff975ae    57121
# 61de932f2cea787beffa32eb    40401
# 6159f38bbab1dd88bd6a3a2b    40000
# 61de94ce2cea787beffa337c    38025
#                             ...
# 6159f38bbab1dd88bd6a43e9        1
# 6159f38bbab1dd88bd6a39a5        1
# 6159f38bbab1dd88bd6a4671        1
# 6159f38bbab1dd88bd6a334a        1
# 6159f38bbab1dd88bd6a4907        1
# Name: Outlet ID, Length: 8027, dtype: int64

# %%
outlet_id =outlet_id.to_csv('outlet_id.csv',index=False)

# %%
test =test.to_csv('test.csv',index=False)

# %%
outlet_id.shape
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7856/780965201.py in <module>
# ----> 1 outlet_id.shape
#
# AttributeError: 'NoneType' object has no attribute 'shape'
