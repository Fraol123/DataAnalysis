# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os

# %%
df = pd.read_csv('sales2.csv')
mm = pd.read_csv('sales.csv')

# %% [markdown]
# ## cleaning the data
#
# drop rows of NAN

# %%
df['Month'] = df['Date'].str[0:1]
df['Month'] = df['Month'].astype('int32')
dt.tail()
# Out:
#                        Sale ID               User User name User last name  \
# 5622  61f931702cea787beffbf11a    lamrot.werkineh    Lamrot       Werkineh
# 5623  61f931702cea787beffbf11a    lamrot.werkineh    Lamrot       Werkineh
# 5624  61f931702cea787beffbf11a    lamrot.werkineh    Lamrot       Werkineh
# 5625  61f931702cea787beffbf11a    lamrot.werkineh    Lamrot       Werkineh
# 5626  61f8ac7e2cea787beffbd8ad  meaza.hailemariam     Meaza    Hailemariam
#
#        Time        Date                 Outlet ID  \
# 5622  06:46  01/02/2022  6159f38bbab1dd88bd6a3bdb
# 5623  06:46  01/02/2022  6159f38bbab1dd88bd6a3bdb
# 5624  06:46  01/02/2022  6159f38bbab1dd88bd6a3bdb
# 5625  06:46  01/02/2022  6159f38bbab1dd88bd6a3bdb
# 5626  06:43  01/02/2022  6159f38bbab1dd88bd6a3c35
#
#                                Outlet         TIN Outlet Segment  ...  \
# 5622                  Mekdi Bar And R        1000    Star Hotels  ...
# ...

# %%
#shape of df
df.shape
# Out:
# (15621, 11)

# %%
#columns present in df
df.columns
# Out:
# Index(['Date', 'Outlet ID', 'Territory', 'Area', 'Outlet', 'Apple', 'GHL',
#        'Lime', 'PG', 'Total', 'Month'],
#       dtype='object')

# %%
#summery of data set
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15621 entries, 0 to 15620
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       15621 non-null  object
#  1   Outlet ID  15621 non-null  object
#  2   Territory  15621 non-null  object
#  3   Area       15621 non-null  object
#  4   Outlet     15621 non-null  object
#  5   Apple      6758 non-null   float64
#  6   GHL        1384 non-null   float64
#  7   Lime       13767 non-null  float64
#  8   PG         8003 non-null   float64
#  9   Total      15621 non-null  int64
#  10  Month      15621 non-null  int32
# dtypes: float64(4), int32(1), int64(1), object(5)
# memory usage: 1.4+ MB

# %%
# checking missing values
df.isnull().sum()
# Out:
# Date             0
# Outlet ID        0
# Territory        0
# Area             0
# Outlet           0
# Apple         8863
# GHL          14237
# Lime          1854
# PG            7618
# Total            0
# Month            0
# dtype: int64

# %%
nan_df = df[df.isna().any(axis=1)]
display(nan_df.head())

df = df.dropna(how='all')
df.head()
# Out:
#          Date                 Outlet ID            Territory  \
# 0  28/02/2022  6159f38bbab1dd88bd6a26d4           WEST ADDIS
# 1  28/02/2022  6159f38bbab1dd88bd6a2708  NORTH CENTRAL ADDIS
# 2  28/02/2022  6159f38bbab1dd88bd6a2716          SOUTH ADDIS
# 3  28/02/2022  6159f38bbab1dd88bd6a274d           WEST ADDIS
# 4  28/02/2022  6159f38bbab1dd88bd6a2775           WEST ADDIS
#
#                    Area                         Outlet  Apple  GHL  Lime   PG  \
# 0    TOREHAYLOCH - ASKO                    1 View Hote    5.0  1.0   NaN  5.0
# 1      LEGEHAR - ENTOTO  5 Kilo Coffee And Restaurant     6.0  NaN  13.0  6.0
# 2   GOTERA - HANAMARIAM             AB Bar&restaurant     NaN  NaN   2.0  NaN
# 3  TOREHAYLOCH - WELETE                      Abe Hotel    NaN  NaN   2.0  NaN
# 4  TOREHAYLOCH - WELETE        Abee Bar And Restaurant    NaN  NaN   5.0  NaN
#
#    Total  Month
# 0     11      2
# 1     25      2
# 2      2      2
# 3      2      2
# 4      5      2
# ...

# %%
df.isnull().sum()
# Out:
# Date             0
# Outlet ID        0
# Territory        0
# Area             0
# Outlet           0
# Apple         8863
# GHL          14237
# Lime          1854
# PG            7618
# Total            0
# Month            0
# dtype: int64

# %%
# getting describe statics of summery
df.describe()
# Out:
#              Apple          GHL          Lime           PG         Total  \
# count  6758.000000  1384.000000  13767.000000  8003.000000  15621.000000
# mean      1.864605     2.170520      3.621559     1.957016      5.193329
# std       2.205282     2.234897      5.513395     2.439859      8.073328
# min       1.000000     1.000000      1.000000     1.000000      1.000000
# 25%       1.000000     1.000000      1.000000     1.000000      2.000000
# 50%       1.000000     1.000000      2.000000     1.000000      3.000000
# 75%       2.000000     2.000000      4.000000     2.000000      6.000000
# max      55.000000    20.000000    166.000000    74.000000    276.000000
#
#               Month
# count  15621.000000
# mean       1.020933
# std        0.792497
# min        0.000000
# 25%        0.000000
# 50%        1.000000
# 75%        2.000000
# max        2.000000

# %%
df.drop("Month", axis=1, inplace=True)

# %%
df.describe()
# Out:
#              Apple          GHL          Lime           PG         Total
# count  6758.000000  1384.000000  13767.000000  8003.000000  15621.000000
# mean      1.864605     2.170520      3.621559     1.957016      5.193329
# std       2.205282     2.234897      5.513395     2.439859      8.073328
# min       1.000000     1.000000      1.000000     1.000000      1.000000
# 25%       1.000000     1.000000      1.000000     1.000000      2.000000
# 50%       1.000000     1.000000      2.000000     1.000000      3.000000
# 75%       2.000000     2.000000      4.000000     2.000000      6.000000
# max      55.000000    20.000000    166.000000    74.000000    276.000000

# %% [markdown]
# # Exploratory Data Analysis

# %%
df['Date'].min()
# Out:
# '01/02/2022'

# %%
df['Date'].max()
# Out:
# '28/02/2022'

# %%
daily_sales = df.groupby('Date').sum()['Total'].reset_index()
daily_sales
# Out:
#           Date  Total
# 0   01/02/2022   2506
# 1   02/02/2022   2596
# 2   03/02/2022   2894
# 3   04/02/2022   2387
# 4   05/02/2022   2833
# 5   06/02/2022    424
# 6   07/02/2022   4018
# 7   08/02/2022   3069
# 8   09/02/2022   2608
# 9   10/02/2022   2569
# 10  11/02/2022   3198
# 11  12/02/2022   3167
# 12  13/02/2022   1120
# 13  14/02/2022   3536
# 14  15/02/2022   3260
# 15  16/02/2022   3131
# 16  17/02/2022   2707
# 17  18/02/2022   3043
# 18  19/02/2022   3367
# 19  20/02/2022   1216
# 20  21/02/2022   3515
# 21  22/02/2022   2931
# 22  23/02/2022   2763
# 23  24/02/2022   3425
# 24  25/02/2022   4433
# 25  26/02/2022   3862
# 26  27/02/2022   1887
# 27  28/02/2022   4660

# %%
# setting fig size
plt.figure(figsize=(15,6))
plt.plot(daily_sales['Date'], daily_sales['Total'], color='red')
plt.xticks(rotation='vertical',size=8)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# <h2> Top saling product

# %%
# grouping product name
dt.head
# Out:
# <bound method NDFrame.head of                        Sale ID               User User name User last name  \
# 0     61ffcdff2cea787beffc7849     zelalem.ayeche   Zelalem         Ayeche
# 1     61ffcdff2cea787beffc7849     zelalem.ayeche   Zelalem         Ayeche
# 2     61ffcdff2cea787beffc7849     zelalem.ayeche   Zelalem         Ayeche
# 3     61ffcdf32cea787beffc7845     zelalem.ayeche   Zelalem         Ayeche
# 4     61ffcde62cea787beffc7841     zelalem.ayeche   Zelalem         Ayeche
# ...                        ...                ...       ...            ...
# 5622  61f931702cea787beffbf11a    lamrot.werkineh    Lamrot       Werkineh
# 5623  61f931702cea787beffbf11a    lamrot.werkineh    Lamrot       Werkineh
# 5624  61f931702cea787beffbf11a    lamrot.werkineh    Lamrot       Werkineh
# 5625  61f931702cea787beffbf11a    lamrot.werkineh    Lamrot       Werkineh
# 5626  61f8ac7e2cea787beffbd8ad  meaza.hailemariam     Meaza    Hailemariam
#
# ...

# %%
prod_sales = dt.DataFrame(dt.groupby('Item name').sum()['Item quantity'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2932/62276529.py in <module>
# ----> 1 prod_sales = dt.DataFrame(dt.groupby('Item name').sum()['Item quantity'])
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'DataFrame'

# %%
dt.columns
# Out:
# Index(['Sale ID', 'User', 'User name', 'User last name', 'Time', 'Date',
#        'Outlet ID', 'Outlet', 'TIN', 'Outlet Segment', 'Vehicle name', 'Area',
#        'Territory', 'District', 'Price without VAT', 'Vat', 'Price with VAT',
#        'Item name', 'Item quantity', 'Item price without VAT', 'Item VAT',
#        'Item price with VAT', 'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24',
#        'Unnamed: 25'],
#       dtype='object')

# %%
dt.columns = dt.columns.str.strip()

# %%
prod_sales = df.DataFrame(df.groupby('Item name').sum()['Item quantity'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2932/146760218.py in <module>
# ----> 1 prod_sales = df.DataFrame(df.groupby('Item name').sum()['Item quantity'])
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'DataFrame'
